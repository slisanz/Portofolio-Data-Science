# %% [markdown]
# # 05 Equity index
#
# Compute the composite, write `commune_equity.parquet`, and sanity-check the ranking.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / 'src'))
# %load_ext autoreload
# %autoreload 2

# %%
from ftth_equity import config, io, equity
df = io.load_parquet(config.INTERIM / 'buildings_clean.parquet')
eq = equity.commune_equity(df)
eq.head(10)
# Out:
#             coverage   pm_load  coll_lag  equity_index  \
# code_insee
# 10230       0.836412  0.395062  0.393939      0.659647
# 10336       0.790780  0.648148  0.333333      0.670764
# 10030       0.941341  0.086420  0.633333      0.708755
# 10329       0.754266  0.580247  0.818182      0.732245
# 10340       0.915974  0.209877  0.729730      0.737506
# 10211       0.892340  0.012346  1.000000      0.737873
# 10406       0.926907  0.024691  0.977273      0.756537
# 10060       0.885121  0.333333  0.802326      0.758204
# 10156       0.891720  0.135802  1.000000      0.762192
# 10357       0.920711  0.320988  0.841463      0.784917
#
#                              nom_com  n_buildings
# code_insee
# 10230                         Mergey          379
# 10336        Saint-Benǫt-sur-Seine          282
# 10030         Barberey-Saint-Sulpice          716
# 10329             Rouilly-Saint-Loup          293
# 10340                  Saint-Germain         1083
# 10211                          Macey          483
# 10406                     Verri̬res          944
# 10060                    Br̩viandes         1445
# 10156                     Fontvannes          314
# 10357       Saint-Parres-aux-Tertres         1463

# %%
io.save_parquet(eq.reset_index(), config.PROCESSED / 'commune_equity.parquet')
# Out:
# WindowsPath('D:/ZE5 PORTOFOLIO DS/FTTH-Equity-Intelligence-Geospatial-ML-Platform/data/processed/commune_equity.parquet')

# %% [markdown]
# ## Sub-indicator correlations

# %%
eq[['coverage','pm_load','coll_lag']].corr()
# Out:
#           coverage   pm_load  coll_lag
# coverage  1.000000  0.085429  0.578658
# pm_load   0.085429  1.000000 -0.052159
# coll_lag  0.578658 -0.052159  1.000000
