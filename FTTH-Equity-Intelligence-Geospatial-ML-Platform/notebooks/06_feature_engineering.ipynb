# %% [markdown]
# # 06 Feature engineering
#
# Build the modeling table the classifier in notebook 07 will consume.

# %%
import sys, os
from pathlib import Path
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT / 'src'))
# %load_ext autoreload
# %autoreload 2

# %%
from ftth_equity import config, io, features
df = io.load_parquet(config.INTERIM / 'buildings_clean.parquet')
tbl = features.build_feature_table(df)
tbl[features.numeric_feature_columns()].describe().T
# Out:
#                              count         mean          std        min  \
# has_building_label         57072.0     0.047063     0.211776   0.000000
# has_postcode               57072.0     1.000000     0.000000   1.000000
# num_voie_filled            57072.0    38.363839   335.076057   0.000000
# is_individuel              57072.0     0.860369     0.346606   0.000000
# is_collective_large        57072.0     0.000000     0.000000   0.000000
# pm_n_buildings             57072.0   317.645991   168.451915   2.000000
# pm_n_communes              57072.0     1.624807     1.032297   1.000000
# pm_n_operators             57072.0     1.000000     0.000000   1.000000
# pm_share_individuel        57072.0     0.860369     0.169407   0.000000
# pm_share_collective_large  57072.0     0.000000     0.000000   0.000000
# com_n_buildings            57072.0  3959.186186  4683.411845  26.000000
# com_n_pm                   57072.0    34.184451    47.765409   1.000000
# com_n_operators            57072.0     1.000000     0.000000   1.000000
# com_share_individuel       57072.0     0.860369     0.115912   0.658857
# com_buildings_per_pm       57072.0   189.212277   100.034577  13.000000
# com_hhi                    57072.0     1.000000     0.000000   1.000000
#
#                                   25%          50%          75%      max
# has_building_label           0.000000     0.000000     0.000000      1.0
# has_postcode                 1.000000     1.000000     1.000000      1.0
# num_voie_filled              5.000000    13.000000    27.000000   9999.0
# is_individuel                1.000000     1.000000     1.000000      1.0
# is_collective_large          0.000000     0.000000     0.000000      0.0
# pm_n_buildings             190.000000   291.000000   434.000000    733.0
# pm_n_communes                1.000000     1.000000     2.000000      7.0
# pm_n_operators               1.000000     1.000000     1.000000      1.0
# pm_share_individuel          0.843434     0.930958     0.956938      1.0
# pm_share_collective_large    0.000000     0.000000     0.000000      0.0
# com_n_buildings            716.000000  1760.000000  3807.000000  12549.0
# com_n_pm                     3.000000    10.000000    26.000000    123.0
# com_n_operators              1.000000     1.000000     1.000000      1.0
# com_share_individuel         0.811885     0.918157     0.949721      1.0
# com_buildings_per_pm       102.024390   167.800000   209.000000    521.0
# com_hhi                      1.000000     1.000000     1.000000      1.0

# %%
io.save_parquet(tbl, config.PROCESSED / 'buildings_features.parquet')
# Out:
# WindowsPath('D:/ZE5 PORTOFOLIO DS/FTTH-Equity-Intelligence-Geospatial-ML-Platform/data/processed/buildings_features.parquet')
